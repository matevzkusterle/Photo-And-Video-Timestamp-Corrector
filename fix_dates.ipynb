# %%
import os
import re
import pywintypes
import win32file
import win32con
import datetime
import piexif
import subprocess
from PIL import Image
from PIL.ExifTags import TAGS
from hachoir.parser import createParser
from hachoir.metadata import extractMetadata

# ------------------ CONFIG ------------------
ROOT_DIR = r'C:\Users\kuste\Desktop\project\Arhiv slik'  # Update this path
IMAGE_EXTS = ['.jpg', '.jpeg', '.JPG', '.JPEG']         # Case-insensitive extensions
VIDEO_EXTS = ['.mp4', '.MP4', '.mov', '.MOV']
YEAR_PATTERN = re.compile(r'\b(20[0-2][0-9]|2030)\b')
EXIFTOOL_PATH = r'C:\ProgramData\chocolatey\bin\exiftool.exe'  # Chocolatey install path
# --------------------------------------------

# ---------- HELPER FUNCTIONS ----------
def is_image(file):
    return any(file.lower().endswith(ext) for ext in IMAGE_EXTS)

def is_video(file):
    return any(file.lower().endswith(ext) for ext in VIDEO_EXTS)

def is_text_file(file):
    return file.lower() == "date.txt"

def get_exif_date(image_path):
    try:
        img = Image.open(image_path)
        exif_data = img._getexif()
        if exif_data:
            for tag_id, value in exif_data.items():
                tag_name = TAGS.get(tag_id, tag_id)
                if tag_name == 'DateTimeOriginal':
                    return datetime.datetime.strptime(value, '%Y:%m:%d %H:%M:%S')
    except Exception as e:
        print(f"⚠️ EXIF read error for {image_path}: {str(e)}")
    return None

def get_video_creation_date(path):
    try:
        parser = createParser(path)
        if not parser:
            return None
        with parser:
            metadata = extractMetadata(parser)
        if metadata and metadata.has("creation_date"):
            return metadata.get("creation_date")
    except Exception as e:
        print(f"⚠️ Video metadata read error for {path}: {str(e)}")
    return None

def parse_date_txt(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            line = f.readline().strip()
            line = line.replace('\u200e', '')  # Remove LTR characters
            return datetime.datetime.strptime(line, "%A, %d %B %Y")
    except Exception as e:
        print(f"❌ Error reading date.txt in {file_path}: {e}")
    return None

def extract_year_from_folder(name):
    match = YEAR_PATTERN.search(name)
    if match:
        return datetime.datetime(int(match.group()), 1, 1)  # Default to Jan 1 of year
    return None

def set_file_times(path, dt):
    try:
        win_time = pywintypes.Time(dt)
        handle = win32file.CreateFile(
            path,
            win32con.GENERIC_WRITE,
            win32con.FILE_SHARE_READ | win32con.FILE_SHARE_WRITE | win32con.FILE_SHARE_DELETE,
            None,
            win32con.OPEN_EXISTING,
            win32con.FILE_ATTRIBUTE_NORMAL,
            None
        )
        win32file.SetFileTime(handle, win_time, win_time, win_time)
        handle.Close()
        return True
    except Exception as e:
        print(f"❌ Failed to set filesystem times for {path}: {e}")
        return False

def update_image_exif_metadata(image_path, dt):
    """Completely updates all EXIF datetime fields in an image"""
    try:
        dt_str = dt.strftime("%Y:%m:%d %H:%M:%S")
        
        # Load existing EXIF or create new
        try:
            exif_dict = piexif.load(image_path)
        except:
            exif_dict = {"0th": {}, "Exif": {}, "GPS": {}, "1st": {}}
            
        # Update all relevant EXIF fields
        exif_dict["Exif"][piexif.ExifIFD.DateTimeOriginal] = dt_str
        exif_dict["Exif"][piexif.ExifIFD.DateTimeDigitized] = dt_str
        exif_dict["0th"][piexif.ImageIFD.DateTime] = dt_str
        
        # Additional fields some phones might check
        exif_dict["Exif"][36867] = dt_str  # DateTimeOriginal (alternate)
        exif_dict["Exif"][36868] = dt_str  # DateTimeDigitized (alternate)
            
        exif_bytes = piexif.dump(exif_dict)
        piexif.insert(exif_bytes, image_path)
        return True
    except Exception as e:
        print(f"❌ EXIF update failed for {image_path}: {e}")
        return False

def update_video_metadata(video_path, dt):
    """Updates video metadata using exiftool"""
    try:
        dt_str = dt.strftime("%Y:%m:%d %H:%M:%S")
        cmd = [
            EXIFTOOL_PATH,
            '-CreateDate=' + dt_str,
            '-ModifyDate=' + dt_str,
            '-TrackCreateDate=' + dt_str,
            '-MediaCreateDate=' + dt_str,
            '-overwrite_original',
            video_path
        ]
        result = subprocess.run(cmd, capture_output=True, text=True, creationflags=subprocess.CREATE_NO_WINDOW)
        if result.returncode != 0:
            print(f"❌ ExifTool failed for {video_path}: {result.stderr}")
            return False
        return True
    except Exception as e:
        print(f"❌ Video metadata update failed for {video_path}: {e}")
        return False

# ---------- MAIN EXECUTION ----------
def main():
    folders_scanned = 0
    files_updated = 0

    # Verify ExifTool is accessible
    try:
        subprocess.run([EXIFTOOL_PATH, '-ver'], check=True, capture_output=True)
    except Exception as e:
        print(f"❌ Critical: ExifTool not found at {EXIFTOOL_PATH}")
        print("Install via Chocolatey: 'choco install exiftool'")
        return

    for dirpath, _, filenames in os.walk(ROOT_DIR):
        folders_scanned += 1
        print(f"\n📁 Processing folder: {os.path.basename(dirpath)}")
        
        txt_date = None
        image_dates = []
        video_dates = []

        # Step 1: Check for date.txt
        for file in filenames:
            if is_text_file(file):
                txt_date = parse_date_txt(os.path.join(dirpath, file))
                if txt_date:
                    print(f"📝 Found date.txt with date: {txt_date.date()}")
                break

        # Step 2: Collect media dates if no txt_date
        if not txt_date:
            for file in filenames:
                full_path = os.path.join(dirpath, file)
                if is_image(file):
                    dt = get_exif_date(full_path)
                    if dt:
                        image_dates.append((file, dt))
                elif is_video(file):
                    dt = get_video_creation_date(full_path)
                    if dt:
                        video_dates.append((file, dt))

        # Step 3: Determine fallback date
        fallback_date = None

        if txt_date:
            fallback_date = txt_date
        elif image_dates:
            fallback_date = sorted(image_dates, key=lambda x: x[1])[-1][1]  # Newest image date
        elif video_dates:
            fallback_date = sorted(video_dates, key=lambda x: x[1])[-1][1]  # Newest video date
        else:
            fallback_date = extract_year_from_folder(os.path.basename(dirpath))

        if not fallback_date:
            print("⚠️ No valid date found. Skipping folder.")
            continue

        print(f"ℹ️ Using reference date: {fallback_date.date()}")

        # Step 4: Process files
        for file in filenames:
            full_path = os.path.join(dirpath, file)

            if is_image(file):
                dt = txt_date or get_exif_date(full_path) or fallback_date
                if update_image_exif_metadata(full_path, dt) and set_file_times(full_path, dt):
                    print(f"✔️ Updated image: {file}")
                    files_updated += 1

            elif is_video(file):
                dt = txt_date or get_video_creation_date(full_path) or fallback_date
                if update_video_metadata(full_path, dt) and set_file_times(full_path, dt):
                    print(f"✔️ Updated video: {file}")
                    files_updated += 1

    print(f"\n✅ Done. Folders scanned: {folders_scanned}, Files updated: {files_updated}")

if __name__ == "__main__":
    main()
# Out:
# 📁 Processing folder: Arhiv slik
# ⚠️ No valid date found. Skipping folder.
#
# 📁 Processing folder: !Prema gore kranjske
# ℹ️ Using reference date: 2021-09-23
# ✔️ Updated image: IMG_20210920_111621.jpg
# ✔️ Updated image: IMG_20210920_112058.jpg
# ✔️ Updated image: IMG_20210921_172137.jpg
# ✔️ Updated image: IMG_20210921_173506.jpg
# ✔️ Updated image: IMG_20210921_175826.jpg
# ✔️ Updated image: IMG_20210923_130216.jpg
# ✔️ Updated image: IMG_20210923_204824-je uredil(-a)_.jpg
# ✔️ Updated image: IMG_20210923_204824.jpg
# ✔️ Updated image: IMG_20210923_204837-je uredil(-a)_.jpg
# ✔️ Updated image: IMG_20210923_204837.jpg
# ✔️ Updated image: received_3173426426226982.jpeg
# ✔️ Updated video: VID_20210922_180333~2.mp4
#
# 📁 Processing folder: Arhiv
# ℹ️ Using reference date: 2024-01-06
# ✔️ Updated image: .trashed-1739827208-WallX_1349137_1080x1920.jpeg
# ✔️ Updated image: 03f53d3f919db3b017d5b66e19dece65.jpg
# ✔️ Updated image: 1119991.jpg
# ✔️ Updated image: 137374_original_2738x3000.jpg
# ✔️ Updated image: 1d14f37c8047758a46100cdaca46d794.jpg
# ✔️ Updated image: 4k-android-i6wkk4dtdymct63b.jpg
# ✔️ Updated image: 57166.jpg
# ✔️ Updated image: 6283118.jpg
# ✔️ Updated image: 7c4eee0569daa6c5ff56613ff26d2e89.jpg
# ✔️ Updated image: 7d0a4fe81e38d7a73224-triglav.jpeg
# ✔️ Updated image: 893582.jpg
# ✔️ Updated image: borussia_dortmund___hd_logo_wallpaper_by_kerimo.jpg
# ✔️ Updated image: FB_IMG_1673221585780.jpg
# ✔️ Updated image: FEDERER-WIMBLEDON-07072021-1353-1-1.jpg
# ✔️ Updated image: Football-Edits-F-Edits-Twitter-wallpaper-wp4404.jpg
# ✔️ Updated image: football-wallpapers-hd-for-android-iphone-footb.jpg
# ✔️ Updated image: Glowing-Earth-HD-Mobile-Wallpaper-950x1520.jpg
# ✔️ Updated image: HD-wallpaper-plain-black-000000-dark-none-pitch.jpg
# ✔️ Updated image: HD-wallpaper-yu-gi-oh-anime-exodia-kaiba.jpg
# ✔️ Updated image: Planet-5f1881a4-4c4e-358b-ac15-f552d561faa6.jpg
# ✔️ Updated image: roger-federer-ap-1600.jpg
# ✔️ Updated image: Screenshot_2022-08-29-23-08-44-81_50ef9f5a0f3fc.jpg
# ✔️ Updated image: Screenshot_2022-08-29-23-09-08-53_50ef9f5a0f3fc.jpg
# ✔️ Updated image: Screenshot_2022-08-29-23-09-54-26_50ef9f5a0f3fc.jpg
# ✔️ Updated image: Screenshot_2022-09-16-01-34-40-64_40deb401b9ffe.jpg
# ✔️ Updated image: Screenshot_2022-11-30-21-46-46-94_3822ac0e29cfe.jpg
# ✔️ Updated image: Screenshot_2024-01-06-01-56-05-40_fe657d718f12c.jpg
# ✔️ Updated image: Screenshot_2024-01-06-01-56-07-57_fe657d718f12c.jpg
# ✔️ Updated image: Screenshot_2024-01-06-01-56-09-40_fe657d718f12c.jpg
# ✔️ Updated image: Screenshot_2024-01-06-01-56-11-25_fe657d718f12c.jpg
# ✔️ Updated image: Screenshot_2024-01-06-01-56-13-50_fe657d718f12c.jpg
# ✔️ Updated image: sky-full-of-stars-nature-4k-62-750x1334.jpg
# ✔️ Updated image: The Road Ahead HD Mobile Wallpaper.jpg
# ✔️ Updated image: WallX_1031492_1080x1920.jpeg
# ✔️ Updated image: WallX_1031639_1080x1920.jpeg
# ✔️ Updated image: WallX_1031817_1080x1920.jpeg
# ✔️ Updated image: WallX_1085796_1080x1920.jpeg
# ✔️ Updated image: WallX_1128298_1080x1920.jpeg
# ✔️ Updated image: WallX_1132547_1080x1920.jpeg
# ✔️ Updated image: WallX_1133415_1080x1920.jpeg
# ✔️ Updated image: WallX_1296362_1080x1920.jpeg
# ✔️ Updated image: WallX_1296760_1080x1920.jpeg
# ✔️ Updated image: WallX_1313880_1080x1920.jpeg
# ✔️ Updated image: WallX_171978_1080x1920.jpeg
# ✔️ Updated image: WallX_902448_1080x1920.jpeg
# ✔️ Updated image: WallX_902851_1080x1920.jpeg
# ✔️ Updated image: WallX_903469_1080x1920.jpeg
# ✔️ Updated image: WallX_909837_1080x1920.jpeg
# ✔️ Updated image: WallX_973214_1080x1920.jpeg
# ✔️ Updated image: WallX_988606_1080x1920.jpeg
# ✔️ Updated image: WallX_paint_grunge_green_124502_720x1280.jpeg
# ✔️ Updated image: WallX_silhouette_starry_sky_shooting_star_1313.jpeg
# ✔️ Updated image: WallX_starry_sky_night_mountains_radiance_glit.jpeg
# ✔️ Updated image: wp9360169.jpg
# ✔️ Updated image: _uhdminimal24.jpg
# ✔️ Updated image: _uhdwomens152.jpg
#
# 📁 Processing folder: hmhm
# ℹ️ Using reference date: 2025-07-25
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\hmhm\IMG20240819205257.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\hmhm\IMG20250725192542.jpg: Given data isn't JPEG.
# ✔️ Updated video: Record_2024-08-23-21-29-05.mp4
# ✔️ Updated image: Screenshot_2024-10-06-21-14-47-33_965bbf4d18d205f782c6b8409c5773a4.jpg
#
# 📁 Processing folder: Memes
# ℹ️ Using reference date: 2023-09-15
# ✔️ Updated image: 20151011_215457.jpg
# ✔️ Updated image: 20160702_235337-je uredil(-a)_.jpg
# ✔️ Updated image: 20160702_235337.jpg
# ✔️ Updated image: 20170128_071758.jpg
# ✔️ Updated image: 20170606_142343.jpg
# ✔️ Updated image: 2323.jpg
# ✔️ Updated image: 511B0hhgs2L._AC_SY355_.jpg
# ✔️ Updated image: 61967ce91d7c716985d5caa6.jpeg
# ✔️ Updated image: Aliens.jpg
# ✔️ Updated image: b634i29bxln21.jpg
# ✔️ Updated image: desktop-wallpaper-11-giga-chad-ideas-giga-chad-.jpg
# ✔️ Updated image: FB_IMG_1639304206150.jpg
# ✔️ Updated image: FB_IMG_1666808946612.jpg
# ✔️ Updated image: FB_IMG_1668870341146.jpg
# ✔️ Updated image: FB_IMG_1673217642904.jpg
# ✔️ Updated image: FB_IMG_1685979781728.jpg
# ✔️ Updated image: FB_IMG_1724502323888.jpg
# ✔️ Updated image: FB_IMG_1725457618132.jpg
# ✔️ Updated image: FB_IMG_1725545025320.jpg
# ✔️ Updated image: FB_IMG_1725655507328.jpg
# ✔️ Updated image: FB_IMG_1725811277124.jpg
# ✔️ Updated image: FB_IMG_1726124880413.jpg
# ✔️ Updated image: FB_IMG_1726138131685.jpg
# ✔️ Updated image: FB_IMG_1728333044287.jpg
# ✔️ Updated image: FB_IMG_1728338767662.jpg
# ✔️ Updated image: FB_IMG_1728372009182.jpg
# ✔️ Updated image: FB_IMG_1728655154391.jpg
# ✔️ Updated image: FB_IMG_1729756165586.jpg
# ✔️ Updated image: fetchimage.jpeg
# ✔️ Updated image: IMG_1507448433601.jpg
# ✔️ Updated image: IMG_20220531_003835_287.jpg
# ✔️ Updated image: IMG_20221122_164550.jpg
# ✔️ Updated image: IMG_20230831_224928_532.jpg
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Memes\jp58smqyecf81~2.mp4: [Errno 22] Invalid argument
# ✔️ Updated image: PERDIH_MEME.jpg
# ✔️ Updated image: pp,840x830-pad,1000x1000,f8f8f8.jpg
# ✔️ Updated image: received_671054871575892.jpeg
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Memes\received_711512116715713.mp4: [Errno 22] Invalid argument
# ✔️ Updated image: received_974646366693466-je uredil(-a)_.jpeg
# ✔️ Updated image: received_974646366693466.jpeg
# ✔️ Updated image: Screenshot_2021-12-13-19-36-56-85_40deb401b9ffe.jpg
# ✔️ Updated image: Screenshot_2022-04-24-01-52-18-91_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2022-05-10-15-16-30-17_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2022-05-26-15-10-09-53_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2022-07-27-23-56-25-36_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2022-10-14-11-38-54-25_a23b203fd3aaf.jpg
# ✔️ Updated image: Screenshot_2022-12-09-22-57-02-89_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2022-12-17-00-41-27-26_40deb401b9ffe.jpg
# ✔️ Updated image: Screenshot_2023-01-16-21-59-53-94_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2023-01-24-16-39-28-32_40deb401b9ffe.jpg
# ✔️ Updated image: Screenshot_2023-04-08-17-12-38-45_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-05-18-23-47-07-57_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-05-18-23-52-19-61_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-05-18-23-53-21-33_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-05-19-00-01-22-20_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-05-28-17-26-31-42_a23b203fd3aaf.jpg
# ✔️ Updated image: Screenshot_2023-06-12-15-40-22-74_a23b203fd3aaf.jpg
# ✔️ Updated image: Screenshot_2023-06-20-16-38-46-36_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2023-06-24-17-30-33-99_ee8807d2de22f.jpg
# ✔️ Updated image: Screenshot_2023-06-24-17-33-39-77_ee8807d2de22f.jpg
# ✔️ Updated image: Screenshot_2023-07-12-16-22-48-70_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2023-07-12-16-27-27-41_965bbf4d18d20.jpg
# ✔️ Updated image: Screenshot_2023-08-18-16-28-35-64_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-08-18-16-28-44-85_1c337646f2987.jpg
# ✔️ Updated image: Screenshot_2023-09-15-16-36-00-61_1c337646f2987.jpg
# ✔️ Updated video: Snapchat-233890274.mp4
# ✔️ Updated video: VID20220101015333.mp4
# ✔️ Updated video: VID20230802165847.mp4
# ✔️ Updated video: VID20230907013914~2.mp4
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Memes\VID_131010125_112705_090.mp4: [Errno 22] Invalid argument
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Memes\VID_20211010_164459~2.mp4: [Errno 22] Invalid argument
# ✔️ Updated video: We are back baby. #shorts #motivation #entrepre.mp4
#
# 📁 Processing folder: ostalo
# ℹ️ Using reference date: 2020-08-24
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\ostalo\c883afee3c093e0ffba7600e4323f570.mp4: [Errno 22] Invalid argument
# ✔️ Updated image: IMG_20200517_021256.jpg
# ✔️ Updated image: IMG_20200517_021308.jpg
# ✔️ Updated image: IMG_20200711_223603.jpg
# ✔️ Updated image: IMG_20200711_223711.jpg
# ✔️ Updated image: IMG_20200726_015923.jpg
# ✔️ Updated image: IMG_20200726_015929.jpg
# ✔️ Updated image: IMG_20200726_015933.jpg
# ✔️ Updated image: IMG_20200807_160016.jpg
# ✔️ Updated image: IMG_20200807_160018.jpg
# ✔️ Updated image: IMG_20200807_160025.jpg
# ✔️ Updated image: IMG_20200807_190545.jpg
# ✔️ Updated image: IMG_20200822_182021.jpg
# ✔️ Updated image: IMG_20200822_182401.jpg
# ✔️ Updated image: IMG_20200822_182411.jpg
# ✔️ Updated image: IMG_20200822_182415.jpg
# ✔️ Updated image: IMG_20200824_194932.jpg
# ✔️ Updated image: InShot_20200709_114557532.jpg
# ✔️ Updated video: VID_20200716_120527.mp4
# ✔️ Updated video: VID_20200807_114022.mp4
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\ostalo\YouCut_20220711_015101696.mp4: [Errno 22] Invalid argument
#
# 📁 Processing folder: ostalo (1)
# ℹ️ Using reference date: 2023-08-01
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\ostalo (1)\IMG20230801053725.jpg: Given data isn't JPEG.
# ✔️ Updated video: VID_20201214_105710.mp4
#
# 📁 Processing folder: Photos from 2015
# ℹ️ Using reference date: 2015-12-27
# ✔️ Updated image: 20150624_195606.jpg
# ✔️ Updated image: 20150624_195712.jpg
# ✔️ Updated image: 20150712_080903-PANO.jpg
# ✔️ Updated image: 20150712_080903.jpg
# ✔️ Updated image: 20150712_080905.jpg
# ✔️ Updated image: 20150712_080913.jpg
# ✔️ Updated image: 20150712_081041.jpg
# ✔️ Updated image: 20150724_122432.jpg
# ✔️ Updated image: 20150724_171315.jpg
# ✔️ Updated image: 20150725_100954.jpg
# ✔️ Updated image: 20150725_101003.jpg
# ✔️ Updated image: 20150808_064555.jpg
# ✔️ Updated image: 20150808_064601_HDR.jpg
# ✔️ Updated image: 20150808_064616.jpg
# ✔️ Updated image: 20150808_064620.jpg
# ✔️ Updated image: 20150808_075920.jpg
# ✔️ Updated image: 20150808_080733.jpg
# ✔️ Updated image: 20150808_080759.jpg
# ✔️ Updated image: 20150817_085542.jpg
# ✔️ Updated image: 20150817_092726.jpg
# ✔️ Updated image: 20151011_215457.jpg
# ✔️ Updated image: 20151023_091036.jpg
# ✔️ Updated image: 20151023_091137.jpg
# ✔️ Updated image: 20151023_091140.jpg
# ✔️ Updated image: 20151023_091928.jpg
# ✔️ Updated image: 20151023_091943.jpg
# ✔️ Updated image: 20151023_095033.jpg
# ✔️ Updated image: 20151023_095042.jpg
# ✔️ Updated image: 20151023_095051.jpg
# ✔️ Updated image: 20151023_095808.jpg
# ✔️ Updated image: 20151023_100240.jpg
# ✔️ Updated image: 20151023_100243.jpg
# ✔️ Updated image: 20151023_113909-1.jpg
# ✔️ Updated image: 20151023_113909.jpg
# ✔️ Updated image: 20151023_114307.jpg
# ✔️ Updated image: 20151023_114313.jpg
# ✔️ Updated image: 20151023_114445.jpg
# ✔️ Updated image: 20151023_145235.jpg
# ✔️ Updated image: 20151023_161754_HDR-PANO.jpg
# ✔️ Updated image: 20151023_161754_HDR.jpg
# ✔️ Updated image: 20151023_161759_HDR.jpg
# ✔️ Updated image: 20151023_161800.jpg
# ✔️ Updated image: 20151023_172324.jpg
# ✔️ Updated image: 20151024_104815.jpg
# ✔️ Updated image: 20151024_105004.jpg
# ✔️ Updated image: 20151024_115733.jpg
# ✔️ Updated image: 20151024_115755.jpg
# ✔️ Updated image: 20151024_121223.jpg
# ✔️ Updated image: 20151024_121506.jpg
# ✔️ Updated image: 20151024_121511.jpg
# ✔️ Updated image: 20151024_121534.jpg
# ✔️ Updated image: 20151024_125350-1.jpg
# ✔️ Updated image: 20151024_130401.jpg
# ✔️ Updated image: 20151024_130927.jpg
# ✔️ Updated image: 20151024_131124.jpg
# ✔️ Updated image: 20151024_161857.jpg
# ✔️ Updated image: 20151024_161956.jpg
# ✔️ Updated image: 20151024_165259.jpg
# ✔️ Updated image: 20151024_165317.jpg
# ✔️ Updated image: 20151024_170227.jpg
# ✔️ Updated image: 20151024_170233.jpg
# ✔️ Updated image: 20151024_170518.jpg
# ✔️ Updated image: 20151024_170623.jpg
# ✔️ Updated image: 20151024_171018.jpg
# ✔️ Updated image: 20151024_171345.jpg
# ✔️ Updated image: 20151024_172516-1.jpg
# ✔️ Updated image: 20151024_172917.jpg
# ✔️ Updated image: 20151024_172933.jpg
# ✔️ Updated image: 20151024_172956.jpg
# ✔️ Updated image: 20151024_173018.jpg
# ✔️ Updated image: 20151024_173030.jpg
# ✔️ Updated image: 20151024_173105.jpg
# ✔️ Updated image: 20151024_173129.jpg
# ✔️ Updated image: 20151024_173249.jpg
# ✔️ Updated image: 20151024_173256.jpg
# ✔️ Updated image: 20151024_173502.jpg
# ✔️ Updated image: 20151025_101744_HDR.jpg
# ✔️ Updated image: 20151025_102423_HDR.jpg
# ✔️ Updated image: 20151025_102501_HDR.jpg
# ✔️ Updated image: 20151025_102515_HDR.jpg
# ✔️ Updated image: 20151025_102530_HDR.jpg
# ✔️ Updated image: 20151025_102752_Pano.jpg
# ✔️ Updated image: 20151025_103205_HDR.jpg
# ✔️ Updated image: 20151025_103244_Pano.jpg
# ✔️ Updated image: 20151025_103641_HDR.jpg
# ✔️ Updated image: 20151025_103703_HDR.jpg
# ✔️ Updated image: 20151025_104004_HDR.jpg
# ✔️ Updated image: 20151025_104008_HDR.jpg
# ✔️ Updated image: 20151025_105407_HDR.jpg
# ✔️ Updated image: 20151122_124227-EFFECTS-je uredil(-a)_.jpg
# ✔️ Updated image: 20151122_124227-EFFECTS.jpg
# ✔️ Updated image: 20151122_124227.jpg
# ✔️ Updated image: 20151122_124236.jpg
# ✔️ Updated image: 20151218_124735.jpg
# ✔️ Updated image: 20151227_141926.jpg
# ✔️ Updated image: 20151227_170758_HDR.jpg
#
# 📁 Processing folder: Photos from 2016
# ℹ️ Using reference date: 2016-09-26
# ✔️ Updated video: 20150818_191804.mp4
# ✔️ Updated image: 20160101_134856.jpg
# ✔️ Updated image: 20160101_142044.jpg
# ✔️ Updated image: 20160101_142131_Pano.jpg
# ✔️ Updated image: 20160101_142433.jpg
# ✔️ Updated image: 20160101_142840.jpg
# ✔️ Updated image: 20160101_145505.jpg
# ✔️ Updated image: 20160101_150311.jpg
# ✔️ Updated image: 20160416_175250.jpg
# ✔️ Updated image: 20160416_175315.jpg
# ✔️ Updated image: 20160430_151827.jpg
# ✔️ Updated image: 20160430_151835.jpg
# ✔️ Updated image: 20160430_154542.jpg
# ✔️ Updated image: 20160525_140930.jpg
# ✔️ Updated image: 20160528_215452.jpg
# ✔️ Updated image: 20160528_215500.jpg
# ✔️ Updated image: 20160528_215750.jpg
# ✔️ Updated image: 20160602_143611.jpg
# ✔️ Updated image: 20160602_162122_HDR.jpg
# ✔️ Updated image: 20160602_162132_HDR.jpg
# ✔️ Updated image: 20160603_103817_HDR.jpg
# ✔️ Updated image: 20160603_103821_HDR.jpg
# ✔️ Updated image: 20160603_113719-PANO.jpg
# ✔️ Updated image: 20160603_113719.jpg
# ✔️ Updated image: 20160603_113729_HDR.jpg
# ✔️ Updated image: 20160603_113736_HDR.jpg
# ✔️ Updated image: 20160603_113737.jpg
# ✔️ Updated image: 20160603_114142-1.jpg
# ✔️ Updated image: 20160603_131338_HDR.jpg
# ✔️ Updated image: 20160603_132308_Pano-1.jpg
# ✔️ Updated image: 20160603_140653_HDR.jpg
# ✔️ Updated image: 20160603_152103_HDR.jpg
# ✔️ Updated image: 20160604_103124_Pano.jpg
# ✔️ Updated image: 20160604_103150.jpg
# ✔️ Updated image: 20160604_151525.jpg
# ✔️ Updated image: 20160604_163825.jpg
# ✔️ Updated image: 20160604_163850.jpg
# ✔️ Updated image: 20160604_174329.jpg
# ✔️ Updated image: 20160617_123719.jpg
# ✔️ Updated image: 20160629_091946.jpg
# ✔️ Updated image: 20160629_092043.jpg
# ✔️ Updated image: 20160702_235337-je uredil(-a)_.jpg
# ✔️ Updated image: 20160702_235337.jpg
# ✔️ Updated image: 20160717_053356.jpg
# ✔️ Updated image: 20160717_053410.jpg
# ✔️ Updated image: 20160729_062952_Pano.jpg
# ✔️ Updated image: 20160729_075501.jpg
# ✔️ Updated image: 20160729_075504.jpg
# ✔️ Updated image: 20160729_075530.jpg
# ✔️ Updated image: 20160729_075536.jpg
# ✔️ Updated image: 20160729_081026.jpg
# ✔️ Updated image: 20160729_081245_HDR.jpg
# ✔️ Updated image: 20160729_081324_HDR.jpg
# ✔️ Updated image: 20160729_081552_Pano.jpg
# ✔️ Updated image: 20160729_081631_Pano.jpg
# ✔️ Updated image: 20160729_084348.jpg
# ✔️ Updated image: 20160729_084417.jpg
# ✔️ Updated image: 20160729_084651.jpg
# ✔️ Updated image: 20160729_091815_HDR.jpg
# ✔️ Updated image: 20160729_091820_HDR.jpg
# ✔️ Updated image: 20160729_093106.jpg
# ✔️ Updated image: 20160729_094854_HDR.jpg
# ✔️ Updated image: 20160729_094857.jpg
# ✔️ Updated image: 20160729_095310.jpg
# ✔️ Updated image: 20160729_095312.jpg
# ✔️ Updated image: 20160729_103352.jpg
# ✔️ Updated image: 20160729_114321.jpg
# ✔️ Updated image: 20160805_231604.jpg
# ✔️ Updated image: 20160805_231607.jpg
# ✔️ Updated image: 20160805_231620.jpg
# ✔️ Updated image: 20160805_232932.jpg
# ✔️ Updated image: 20160806_090511.jpg
# ✔️ Updated image: 20160806_090539.jpg
# ✔️ Updated image: 20160806_090616_Pano.jpg
# ✔️ Updated image: 20160806_090855.jpg
# ✔️ Updated image: 20160806_165222.jpg
# ✔️ Updated image: 20160806_165249.jpg
# ✔️ Updated image: 20160806_165537.jpg
# ✔️ Updated image: 20160806_165731.jpg
# ✔️ Updated image: 20160806_180400.jpg
# ✔️ Updated image: 20160806_180503.jpg
# ✔️ Updated image: 20160806_205654.jpg
# ✔️ Updated image: 20160806_205734.jpg
# ✔️ Updated image: 20160806_231901_HDR.jpg
# ✔️ Updated image: 20160807_123609.jpg
# ✔️ Updated image: 20160809_055642_HDR.jpg
# ✔️ Updated image: 20160809_061942_HDR.jpg
# ✔️ Updated image: 20160809_061949.jpg
# ✔️ Updated image: 20160809_062502_HDR.jpg
# ✔️ Updated image: 20160809_062556_HDR.jpg
# ✔️ Updated image: 20160809_063514.jpg
# ✔️ Updated image: 20160809_063519.jpg
# ✔️ Updated image: 20160809_063831.jpg
# ✔️ Updated image: 20160809_064045.jpg
# ✔️ Updated image: 20160809_064116.jpg
# ✔️ Updated image: 20160809_064658.jpg
# ✔️ Updated image: 20160809_064728_Pano.jpg
# ✔️ Updated image: 20160809_065658_Pano.jpg
# ✔️ Updated image: 20160809_070244.jpg
# ✔️ Updated image: 20160809_070721.jpg
# ✔️ Updated image: 20160809_070731_HDR.jpg
# ✔️ Updated image: 20160809_072546_Pano.jpg
# ✔️ Updated image: 20160809_072558.jpg
# ✔️ Updated image: 20160809_073029_HDR.jpg
# ✔️ Updated image: 20160809_073034.jpg
# ✔️ Updated image: 20160809_073512.jpg
# ✔️ Updated image: 20160809_074936.jpg
# ✔️ Updated image: 20160809_075115.jpg
# ✔️ Updated image: 20160809_075155_Pano.jpg
# ✔️ Updated image: 20160809_075231.jpg
# ✔️ Updated image: 20160816_174700.jpg
# ✔️ Updated image: 20160826_073011_HDR.jpg
# ✔️ Updated image: 20160826_073012.jpg
# ✔️ Updated image: 20160826_073018.jpg
# ✔️ Updated image: 20160826_074843.jpg
# ✔️ Updated image: 20160826_080515.jpg
# ✔️ Updated image: 20160826_080520.jpg
# ✔️ Updated image: 20160826_081810_Pano.jpg
# ✔️ Updated image: 20160826_085824_HDR.jpg
# ✔️ Updated image: 20160826_091400_HDR.jpg
# ✔️ Updated image: 20160826_091411_HDR.jpg
# ✔️ Updated image: 20160826_091412.jpg
# ✔️ Updated image: 20160826_092818_Pano.jpg
# ✔️ Updated image: 20160826_092850_Pano.jpg
# ✔️ Updated image: 20160826_094045.jpg
# ✔️ Updated image: 20160826_094053.jpg
# ✔️ Updated image: 20160826_094059.jpg
# ✔️ Updated image: 20160826_101548.jpg
# ✔️ Updated image: 20160826_101624_Pano.jpg
# ✔️ Updated image: 20160826_104755.jpg
# ✔️ Updated image: 20160826_115654.jpg
# ✔️ Updated image: 20160826_115701.jpg
# ✔️ Updated image: 20160826_115713.jpg
# ✔️ Updated image: 20160826_115723.jpg
# ✔️ Updated image: 20160826_115734.jpg
# ✔️ Updated image: 20160826_125115.jpg
# ✔️ Updated image: 20160826_125127.jpg
# ✔️ Updated image: 20160826_133802.jpg
# ✔️ Updated image: 20160826_133813.jpg
# ✔️ Updated image: 20160826_134919.jpg
# ✔️ Updated image: 20160826_135024_Pano.jpg
# ✔️ Updated image: 20160826_135413.jpg
# ✔️ Updated image: 20160826_135436.jpg
# ✔️ Updated image: 20160826_135440.jpg
# ✔️ Updated image: 20160826_135513.jpg
# ✔️ Updated image: 20160826_135517.jpg
# ✔️ Updated image: 20160826_141432.jpg
# ✔️ Updated image: 20160826_141434.jpg
# ✔️ Updated image: 20160826_141456.jpg
# ✔️ Updated image: 20160826_141624_Pano.jpg
# ✔️ Updated image: 20160826_142032_Pano.jpg
# ✔️ Updated image: 20160826_142100.jpg
# ✔️ Updated image: 20160826_142221.jpg
# ✔️ Updated image: 20160826_142742.jpg
# ✔️ Updated image: 20160826_172406_Pano.jpg
# ✔️ Updated image: 20160826_172430.jpg
# ✔️ Updated image: 20160827_073910.jpg
# ✔️ Updated image: 20160827_073913.jpg
# ✔️ Updated image: 20160827_075907.jpg
# ✔️ Updated image: 20160827_075925.jpg
# ✔️ Updated image: 20160827_094602_HDR.jpg
# ✔️ Updated image: 20160901_214450_Pano.jpg
# ✔️ Updated image: 20160901_214516.jpg
# ✔️ Updated image: 20160901_214544_Pano.jpg
# ✔️ Updated image: 20160901_214651.jpg
# ✔️ Updated image: 20160904_102846.jpg
# ✔️ Updated image: 20160910_231452.jpg
# ✔️ Updated image: 20160913_082309.jpg
# ✔️ Updated image: 20160920_144350_HDR.jpg
# ✔️ Updated image: 20160922_142534_HDR.jpg
# ✔️ Updated image: 20160926_090953.jpg
# ✔️ Updated image: 20160926_091000.jpg
# ✔️ Updated video: 20161125_194539.mp4
# ✔️ Updated video: 20161125_194741.mp4
# ✔️ Updated image: DSC_0343.JPG
# ✔️ Updated image: DSC_0344.JPG
# ✔️ Updated image: DSC_0347.JPG
# ✔️ Updated image: DSC_0348.JPG
# ✔️ Updated image: DSC_0361.JPG
# ✔️ Updated image: DSC_0365.JPG
# ✔️ Updated image: DSC_0372.JPG
# ✔️ Updated image: DSC_0376.JPG
# ✔️ Updated image: DSC_0388.JPG
# ✔️ Updated image: DSC_0395.JPG
# ✔️ Updated image: DSC_0397.JPG
# ✔️ Updated image: DSC_0403.JPG
# ✔️ Updated image: DSC_0407.JPG
# ✔️ Updated image: DSC_0408.JPG
# ✔️ Updated image: DSC_0412.JPG
# ✔️ Updated image: DSC_0418.JPG
# ✔️ Updated image: DSC_0419.JPG
# ✔️ Updated image: DSC_0422.JPG
# ✔️ Updated video: MOVIE(1).mp4
# ✔️ Updated video: MOVIE.mp4
#
# 📁 Processing folder: Photos from 2017
# ℹ️ Using reference date: 2017-07-17
# ✔️ Updated video: 20160904_010931.mp4
# ✔️ Updated image: 20170109_214928.jpg
# ✔️ Updated image: 20170128_071758.jpg
# ✔️ Updated image: 20170128_071911.jpg
# ✔️ Updated image: 20170128_132905_Pano.jpg
# ✔️ Updated image: 20170312_094423.jpg
# ✔️ Updated image: 20170314_154521.jpg
# ✔️ Updated image: 20170415_170451.jpg
# ✔️ Updated image: 20170415_170459.jpg
# ✔️ Updated image: 20170415_170531_Pano.jpg
# ✔️ Updated image: 20170415_170607.jpg
# ✔️ Updated image: 20170415_170630.jpg
# ✔️ Updated image: 20170415_170840.jpg
# ✔️ Updated image: 20170415_171136.jpg
# ✔️ Updated image: 20170422_133350.jpg
# ✔️ Updated image: 20170422_173913.jpg
# ✔️ Updated image: 20170422_174023.jpg
# ✔️ Updated image: 20170506_203437-1.jpg
# ✔️ Updated image: 20170506_203437-2.jpg
# ✔️ Updated image: 20170511_120415.jpg
# ✔️ Updated image: 20170511_120456.jpg
# ✔️ Updated image: 20170511_120511.jpg
# ✔️ Updated image: 20170511_120544.jpg
# ✔️ Updated image: 20170511_133711.jpg
# ✔️ Updated image: 20170512_004834.jpg
# ✔️ Updated image: 20170512_080506.jpg
# ✔️ Updated image: 20170512_080515.jpg
# ✔️ Updated image: 20170512_090628_HDR.jpg
# ✔️ Updated image: 20170512_090648.jpg
# ✔️ Updated image: 20170512_092622.jpg
# ✔️ Updated image: 20170512_092651.jpg
# ✔️ Updated image: 20170512_093400.jpg
# ✔️ Updated image: 20170512_094137.jpg
# ✔️ Updated image: 20170512_094506.jpg
# ✔️ Updated image: 20170512_094543_Pano.jpg
# ✔️ Updated image: 20170512_094802.jpg
# ✔️ Updated image: 20170512_095822.jpg
# ✔️ Updated image: 20170512_104710.jpg
# ✔️ Updated image: 20170512_104731_Pano.jpg
# ✔️ Updated image: 20170512_115931_HDR.jpg
# ✔️ Updated image: 20170512_122447_Pano.jpg
# ✔️ Updated image: 20170512_125630_Pano.jpg
# ✔️ Updated image: 20170512_163907_Pano.jpg
# ✔️ Updated image: 20170512_164802.jpg
# ✔️ Updated image: 20170512_202123.jpg
# ✔️ Updated image: 20170512_202139_Pano.jpg
# ✔️ Updated image: 20170512_202204_Pano.jpg
# ✔️ Updated image: 20170512_204944.jpg
# ✔️ Updated image: 20170513_084732_HDR.jpg
# ✔️ Updated image: 20170513_100539.jpg
# ✔️ Updated image: 20170513_100647.jpg
# ✔️ Updated image: 20170513_100713.jpg
# ✔️ Updated image: 20170513_101025_Pano.jpg
# ✔️ Updated image: 20170513_101042.jpg
# ✔️ Updated image: 20170513_101337.jpg
# ✔️ Updated image: 20170513_102120_Pano.jpg
# ✔️ Updated image: 20170513_102142_Pano.jpg
# ✔️ Updated image: 20170513_102509.jpg
# ✔️ Updated image: 20170513_102518.jpg
# ✔️ Updated image: 20170513_103319.jpg
# ✔️ Updated image: 20170513_103322.jpg
# ✔️ Updated image: 20170513_104000.jpg
# ✔️ Updated image: 20170513_104009.jpg
# ✔️ Updated image: 20170513_105010_Pano.jpg
# ✔️ Updated image: 20170513_110421_HDR.jpg
# ✔️ Updated image: 20170513_110427.jpg
# ✔️ Updated image: 20170513_110431.jpg
# ✔️ Updated image: 20170529_085752.jpg
# ✔️ Updated image: 20170529_085754.jpg
# ✔️ Updated image: 20170529_085801.jpg
# ✔️ Updated image: 20170529_175929.jpg
# ✔️ Updated image: 20170530_081526.jpg
# ✔️ Updated image: 20170530_083951.jpg
# ✔️ Updated image: 20170530_083955.jpg
# ✔️ Updated image: 20170530_084116.jpg
# ✔️ Updated image: 20170530_090953.jpg
# ✔️ Updated image: 20170530_091016_Pano.jpg
# ✔️ Updated image: 20170530_164619.jpg
# ✔️ Updated image: 20170530_164639.jpg
# ✔️ Updated image: 20170530_164744.jpg
# ✔️ Updated image: 20170530_171349.jpg
# ✔️ Updated image: 20170530_171905.jpg
# ✔️ Updated image: 20170530_172051.jpg
# ✔️ Updated image: 20170530_174632.jpg
# ✔️ Updated image: 20170530_180728.jpg
# ✔️ Updated image: 20170530_180733.jpg
# ✔️ Updated image: 20170530_180735.jpg
# ✔️ Updated image: 20170530_202326.jpg
# ✔️ Updated image: 20170530_202330.jpg
# ✔️ Updated image: 20170530_203500.jpg
# ✔️ Updated image: 20170530_204228_Pano.jpg
# ✔️ Updated image: 20170530_204328_HDR.jpg
# ✔️ Updated image: 20170530_204426_HDR.jpg
# ✔️ Updated image: 20170530_204505_Pano.jpg
# ✔️ Updated image: 20170530_204728.jpg
# ✔️ Updated image: 20170531_091445_HDR.jpg
# ✔️ Updated image: 20170531_091501.jpg
# ✔️ Updated image: 20170531_092932.jpg
# ✔️ Updated image: 20170531_093303.jpg
# ✔️ Updated image: 20170531_093306.jpg
# ✔️ Updated image: 20170531_093340_Pano.jpg
# ✔️ Updated image: 20170531_093504.jpg
# ✔️ Updated image: 20170531_100835.jpg
# ✔️ Updated image: 20170531_160254.jpg
# ✔️ Updated image: 20170531_160545_Pano.jpg
# ✔️ Updated image: 20170531_160604.jpg
# ✔️ Updated image: 20170531_161004.jpg
# ✔️ Updated image: 20170531_161028_Pano.jpg
# ✔️ Updated image: 20170531_235231.jpg
# ✔️ Updated image: 20170606_142343.jpg
# ✔️ Updated image: 20170617_205242.jpg
# ✔️ Updated image: 20170617_214050.jpg
# ✔️ Updated image: 20170630_120442.jpg
# ✔️ Updated image: 20170630_120505.jpg
# ✔️ Updated image: 20170705_095838.jpg
# ✔️ Updated image: 20170709_190358.jpg
# ✔️ Updated image: 20170709_190414.jpg
# ✔️ Updated image: 20170711_153406.jpg
# ✔️ Updated image: 20170711_153448.jpg
# ✔️ Updated image: 20170711_162642_HDR.jpg
# ✔️ Updated image: 20170711_192037.jpg
# ✔️ Updated image: 20170711_192038.jpg
# ✔️ Updated image: 20170711_192456.jpg
# ✔️ Updated image: 20170711_192812.jpg
# ✔️ Updated image: 20170711_192824.jpg
# ✔️ Updated image: 20170711_205602.jpg
# ✔️ Updated image: 20170712_181436.jpg
# ✔️ Updated image: 20170712_184728.jpg
# ✔️ Updated image: 20170712_190321.jpg
# ✔️ Updated image: 20170712_190336.jpg
# ✔️ Updated image: 20170712_190344.jpg
# ✔️ Updated image: 20170712_193146_HDR.jpg
# ✔️ Updated image: 20170712_200231.jpg
# ✔️ Updated image: 20170712_200236.jpg
# ✔️ Updated image: 20170712_200323.jpg
# ✔️ Updated image: 20170712_200325.jpg
# ✔️ Updated image: 20170712_200331.jpg
# ✔️ Updated image: 20170712_200412.jpg
# ✔️ Updated image: 20170717_065220.jpg
# ✔️ Updated image: 20170717_070030.jpg
# ✔️ Updated image: 20170717_075423_HDR.jpg
# ✔️ Updated image: 20170717_084438.jpg
# ✔️ Updated image: 20170717_084449_HDR.jpg
# ✔️ Updated image: 20170717_084545.jpg
# ✔️ Updated image: 20170717_084625.jpg
# ✔️ Updated image: 20170717_084703.jpg
# ✔️ Updated image: 20170717_084718.jpg
# ✔️ Updated image: 20170717_092925.jpg
# ✔️ Updated image: IMG_1507448433601.jpg
# ✔️ Updated image: IMG_20170512_001736.jpg
# ✔️ Updated image: IMG_20170512_211135.jpg
# ✔️ Updated image: mms_img314041818.jpg
# ✔️ Updated video: Rekorder.mp4
# ✔️ Updated video: VID_20170725_111832.mp4
#
# 📁 Processing folder: Photos from 2018
# ℹ️ Using reference date: 2018-12-31
# ✔️ Updated image: FB_IMG_1524432638614.jpg
# ✔️ Updated image: FB_IMG_1524432648373.jpg
# ✔️ Updated image: FB_IMG_1525114610843.jpg
# ✔️ Updated image: FB_IMG_1526646986062.jpg
# ✔️ Updated image: FB_IMG_1529613186911.jpg
# ✔️ Updated image: IMG_20180203_161435.jpg
# ✔️ Updated image: IMG_20180422_105318.jpg
# ✔️ Updated image: IMG_20180422_194152.jpg
# ✔️ Updated image: IMG_20180422_194223.jpg
# ✔️ Updated image: IMG_20180422_194231.jpg
# ✔️ Updated image: IMG_20180425_130542.jpg
# ✔️ Updated image: IMG_20180425_130549.jpg
# ✔️ Updated image: IMG_20180425_161844.jpg
# ✔️ Updated image: IMG_20180425_163928.jpg
# ✔️ Updated image: IMG_20180425_201409.jpg
# ✔️ Updated image: IMG_20180425_201413.jpg
# ✔️ Updated image: IMG_20180425_201420.jpg
# ✔️ Updated image: IMG_20180426_001035.jpg
# ✔️ Updated image: IMG_20180426_001040.jpg
# ✔️ Updated image: IMG_20180426_001045.jpg
# ✔️ Updated image: IMG_20180426_001049.jpg
# ✔️ Updated image: IMG_20180426_105308.jpg
# ✔️ Updated image: IMG_20180426_113605.jpg
# ✔️ Updated image: IMG_20180426_113955.jpg
# ✔️ Updated image: IMG_20180426_114037.jpg
# ✔️ Updated image: IMG_20180426_114051.jpg
# ✔️ Updated image: IMG_20180426_114132.jpg
# ✔️ Updated image: IMG_20180426_114310.jpg
# ✔️ Updated image: IMG_20180426_114359.jpg
# ✔️ Updated image: IMG_20180426_114937.jpg
# ✔️ Updated image: IMG_20180426_120822.jpg
# ✔️ Updated image: IMG_20180426_120838.jpg
# ✔️ Updated image: IMG_20180426_140724.jpg
# ✔️ Updated image: IMG_20180426_141533.jpg
# ✔️ Updated image: IMG_20180426_141539.jpg
# ✔️ Updated image: IMG_20180426_142625.jpg
# ✔️ Updated image: IMG_20180426_142800.jpg
# ✔️ Updated image: IMG_20180426_142804.jpg
# ✔️ Updated image: IMG_20180426_145319.jpg
# ✔️ Updated image: IMG_20180426_145946.jpg
# ✔️ Updated image: IMG_20180426_150245.jpg
# ✔️ Updated image: IMG_20180426_162730.jpg
# ✔️ Updated image: IMG_20180426_162734.jpg
# ✔️ Updated image: IMG_20180426_162750.jpg
# ✔️ Updated image: IMG_20180426_163706.jpg
# ✔️ Updated image: IMG_20180426_163727.jpg
# ✔️ Updated image: IMG_20180426_163730.jpg
# ✔️ Updated image: IMG_20180426_184244.jpg
# ✔️ Updated image: IMG_20180426_184248.jpg
# ✔️ Updated image: IMG_20180426_184453.jpg
# ✔️ Updated image: IMG_20180426_184500.jpg
# ✔️ Updated image: IMG_20180426_224713.jpg
# ✔️ Updated image: IMG_20180426_224948.jpg
# ✔️ Updated image: IMG_20180426_225332.jpg
# ✔️ Updated image: IMG_20180426_225336.jpg
# ✔️ Updated image: IMG_20180427_095607.jpg
# ✔️ Updated image: IMG_20180427_095950.jpg
# ✔️ Updated image: IMG_20180427_100124.jpg
# ✔️ Updated image: IMG_20180427_100133.jpg
# ✔️ Updated image: IMG_20180427_112837.jpg
# ✔️ Updated image: IMG_20180427_112851.jpg
# ✔️ Updated image: IMG_20180427_113458.jpg
# ✔️ Updated image: IMG_20180427_182455.jpg
# ✔️ Updated image: IMG_20180427_182503.jpg
# ✔️ Updated image: IMG_20180427_182718.jpg
# ✔️ Updated image: IMG_20180428_093456.jpg
# ✔️ Updated image: IMG_20180428_093459.jpg
# ✔️ Updated image: IMG_20180428_093504.jpg
# ✔️ Updated image: IMG_20180428_093508.jpg
# ✔️ Updated image: IMG_20180428_093526.jpg
# ✔️ Updated image: IMG_20180428_105947.jpg
# ✔️ Updated image: IMG_20180428_110053.jpg
# ✔️ Updated image: IMG_20180428_124655.jpg
# ✔️ Updated image: IMG_20180428_125128.jpg
# ✔️ Updated image: IMG_20180428_125132.jpg
# ✔️ Updated image: IMG_20180428_130101.jpg
# ✔️ Updated image: IMG_20180428_131055.jpg
# ✔️ Updated image: IMG_20180428_131122.jpg
# ✔️ Updated image: IMG_20180428_160612.jpg
# ✔️ Updated image: IMG_20180428_160622.jpg
# ✔️ Updated image: IMG_20180428_160752.jpg
# ✔️ Updated image: IMG_20180428_160755.jpg
# ✔️ Updated image: IMG_20180428_160843.jpg
# ✔️ Updated image: IMG_20180428_161008.jpg
# ✔️ Updated image: IMG_20180428_161107.jpg
# ✔️ Updated image: IMG_20180428_161138.jpg
# ✔️ Updated image: IMG_20180428_161345.jpg
# ✔️ Updated image: IMG_20180428_161356.jpg
# ✔️ Updated image: IMG_20180428_161539.jpg
# ✔️ Updated image: IMG_20180428_161610.jpg
# ✔️ Updated image: IMG_20180428_161646.jpg
# ✔️ Updated image: IMG_20180428_161743.jpg
# ✔️ Updated image: IMG_20180428_162217.jpg
# ✔️ Updated image: IMG_20180429_084011.jpg
# ✔️ Updated image: IMG_20180429_084113.jpg
# ✔️ Updated image: IMG_20180429_084826.jpg
# ✔️ Updated image: IMG_20180429_091704.jpg
# ✔️ Updated image: IMG_20180429_091711.jpg
# ✔️ Updated image: IMG_20180429_092414.jpg
# ✔️ Updated image: IMG_20180429_094200.jpg
# ✔️ Updated image: IMG_20180429_095117.jpg
# ✔️ Updated image: IMG_20180429_154843.jpg
# ✔️ Updated image: IMG_20180429_163912.jpg
# ✔️ Updated image: IMG_20180429_165156.jpg
# ✔️ Updated image: IMG_20180429_174350.jpg
# ✔️ Updated image: IMG_20180430_095321.jpg
# ✔️ Updated image: IMG_20180430_143715.jpg
# ✔️ Updated image: IMG_20180430_143720.jpg
# ✔️ Updated image: IMG_20180430_144305.jpg
# ✔️ Updated image: IMG_20180430_144335.jpg
# ✔️ Updated image: IMG_20180430_144442.jpg
# ✔️ Updated image: IMG_20180430_145039.jpg
# ✔️ Updated image: IMG_20180430_145129.jpg
# ✔️ Updated image: IMG_20180430_145152.jpg
# ✔️ Updated image: IMG_20180430_145836.jpg
# ✔️ Updated image: IMG_20180430_145922.jpg
# ✔️ Updated image: IMG_20180430_145953.jpg
# ✔️ Updated image: IMG_20180430_150321.jpg
# ✔️ Updated image: IMG_20180430_150324.jpg
# ✔️ Updated image: IMG_20180512_101429.jpg
# ✔️ Updated image: IMG_20180521_080538.jpg
# ✔️ Updated image: IMG_20180523_161807.jpg
# ✔️ Updated image: IMG_20180601_101705.jpg
# ✔️ Updated image: IMG_20180601_101725.jpg
# ✔️ Updated image: IMG_20180602_094748.jpg
# ✔️ Updated image: IMG_20180602_094800.jpg
# ✔️ Updated image: IMG_20180616_085347_BURST001_COVER.jpg
# ✔️ Updated image: IMG_20180616_085347_BURST002.jpg
# ✔️ Updated image: IMG_20180616_085347_BURST003.jpg
# ✔️ Updated image: IMG_20180618_122719.jpg
# ✔️ Updated image: IMG_20180618_182228.jpg
# ✔️ Updated image: IMG_20180618_182813.jpg
# ✔️ Updated image: IMG_20180618_183614.jpg
# ✔️ Updated image: IMG_20180620_072249.jpg
# ✔️ Updated image: IMG_20180621_181203.jpg
# ✔️ Updated image: IMG_20180621_182146.jpg
# ✔️ Updated image: IMG_20180621_182656.jpg
# ✔️ Updated image: IMG_20180621_183228.jpg
# ✔️ Updated image: IMG_20180624_135200.jpg
# ✔️ Updated image: IMG_20180624_135208_017.jpg
# ✔️ Updated image: IMG_20180627_122211.jpg
# ✔️ Updated image: IMG_20180630_203955.jpg
# ✔️ Updated image: IMG_20180701_115646.jpg
# ✔️ Updated image: IMG_20180708_000037.jpg
# ✔️ Updated image: IMG_20180708_230922.jpg
# ✔️ Updated image: IMG_20180728_061227.jpg
# ✔️ Updated image: IMG_20180728_082347.jpg
# ✔️ Updated image: IMG_20180804_161726.jpg
# ✔️ Updated image: IMG_20180804_162847.jpg
# ✔️ Updated image: IMG_20180805_160516.jpg
# ✔️ Updated image: IMG_20180805_161237.jpg
# ✔️ Updated image: IMG_20180805_161238.jpg
# ✔️ Updated image: IMG_20180806_123345.jpg
# ✔️ Updated image: IMG_20180806_194152.jpg
# ✔️ Updated image: IMG_20180806_194218.jpg
# ✔️ Updated image: IMG_20180806_201701.jpg
# ✔️ Updated image: IMG_20180818_195125.jpg
# ✔️ Updated image: IMG_20180818_195129.jpg
# ✔️ Updated image: IMG_20180819_094230.jpg
# ✔️ Updated image: IMG_20180819_094250.jpg
# ✔️ Updated image: IMG_20180822_181902.jpg
# ✔️ Updated image: IMG_20180822_181907.jpg
# ✔️ Updated image: IMG_20180822_181910.jpg
# ✔️ Updated image: IMG_20180822_181915.jpg
# ✔️ Updated image: IMG_20180831_113952.jpg
# ✔️ Updated image: IMG_20180903_165449.jpg
# ✔️ Updated image: IMG_20180905_155502.jpg
# ✔️ Updated image: IMG_20180905_191922-EFFECTS-je uredil(-a)_.jpg
# ✔️ Updated image: IMG_20180905_191922-EFFECTS.jpg
# ✔️ Updated image: IMG_20180923_165955.jpg
# ✔️ Updated image: IMG_20180926_191136.jpg
# ✔️ Updated image: IMG_20181012_144841.jpg
# ✔️ Updated image: IMG_20181013_165240.jpg
# ✔️ Updated image: IMG_20181013_204236.jpg
# ✔️ Updated image: IMG_20181013_204624.jpg
# ✔️ Updated image: IMG_20181013_213832.jpg
# ✔️ Updated image: IMG_20181014_125847.jpg
# ✔️ Updated image: IMG_20181014_131940_889.jpg
# ✔️ Updated image: IMG_20181017_183014.jpg
# ✔️ Updated image: IMG_20181017_183022.jpg
# ✔️ Updated image: IMG_20181101_235115.jpg
# ✔️ Updated image: IMG_20181101_235121.jpg
# ✔️ Updated image: IMG_20181110_092811.jpg
# ✔️ Updated image: IMG_20181117_114840.jpg
# ✔️ Updated image: IMG_20181117_114937.jpg
# ✔️ Updated image: IMG_20181117_120930.jpg
# ✔️ Updated image: IMG_20181117_120936.jpg
# ✔️ Updated image: IMG_20181117_121005.jpg
# ✔️ Updated image: IMG_20181117_121009.jpg
# ✔️ Updated image: IMG_20181203_190251_935.jpg
# ✔️ Updated image: IMG_20181203_190251_939.jpg
# ✔️ Updated image: IMG_20181207_202534_190.jpg
# ✔️ Updated image: IMG_20181208_163417.jpg
# ✔️ Updated image: IMG_20181208_164011.jpg
# ✔️ Updated image: IMG_20181208_164021.jpg
# ✔️ Updated image: IMG_20181210_085632.jpg
# ✔️ Updated image: IMG_20181215_183508.jpg
# ✔️ Updated image: IMG_20181215_183514.jpg
# ✔️ Updated image: IMG_20181218_095335_BURST001_COVER.jpg
# ✔️ Updated image: IMG_20181218_095335_BURST002.jpg
# ✔️ Updated image: IMG_20181218_095335_BURST003.jpg
# ✔️ Updated image: IMG_20181221_103220.jpg
# ✔️ Updated image: IMG_20181230_075911.jpg
# ✔️ Updated image: IMG_20181230_075912.jpg
# ✔️ Updated image: IMG_20181230_075943.jpg
# ✔️ Updated image: IMG_20181230_080201.jpg
# ✔️ Updated image: IMG_20181230_080222.jpg
# ✔️ Updated image: IMG_20181230_085759.jpg
# ✔️ Updated image: IMG_20181230_090353.jpg
# ✔️ Updated image: IMG_20181230_090937.jpg
# ✔️ Updated image: IMG_20181230_093055.jpg
# ✔️ Updated image: IMG_20181230_093304.jpg
# ✔️ Updated image: IMG_20181230_093310.jpg
# ✔️ Updated image: IMG_20181231_231950.jpg
# ✔️ Updated image: IMG_20181231_233228.jpg
# ✔️ Updated image: IMG_20190603_160011.jpg
# ✔️ Updated image: PART_1544296776552.jpeg
# ✔️ Updated image: PART_1544296785057.jpeg
# ✔️ Updated image: Snapchat-1660778579.jpg
# ✔️ Updated video: VID_20180427_224505.mp4
# ✔️ Updated video: VID_20180624_134653.mp4
# ✔️ Updated video: VID_20181230_092828.mp4
# ✔️ Updated video: VID_53730101_143239_707.mp4
#
# 📁 Processing folder: Photos from 2019
# ℹ️ Using reference date: 2019-12-29
# ✔️ Updated image: 20190428_192036_HDR.jpg
# ✔️ Updated image: 20190803_231940.jpg
# ✔️ Updated image: b634i29bxln21.jpg
# ✔️ Updated image: EFFECTS-je uredil(-a)_.jpg
# ✔️ Updated image: EFFECTS.jpg
# ✔️ Updated image: FB_IMG_1576347597675.jpg
# ✔️ Updated image: IMG_20190101_011345.jpg
# ✔️ Updated image: IMG_20190101_011848.jpg
# ✔️ Updated image: IMG_20190105_143240.jpg
# ✔️ Updated image: IMG_20190106_000059.jpg
# ✔️ Updated image: IMG_20190126_095240.jpg
# ✔️ Updated image: IMG_20190126_100157.jpg
# ✔️ Updated image: IMG_20190126_100208.jpg
# ✔️ Updated image: IMG_20190205_173311.jpg
# ✔️ Updated image: IMG_20190205_173346.jpg
# ✔️ Updated image: IMG_20190207_193328.jpg
# ✔️ Updated image: IMG_20190207_193746.jpg
# ✔️ Updated image: IMG_20190207_193820.jpg
# ✔️ Updated image: IMG_20190207_194808.jpg
# ✔️ Updated image: IMG_20190207_194816.jpg
# ✔️ Updated image: IMG_20190208_124910.jpg
# ✔️ Updated image: IMG_20190215_183005.jpg
# ✔️ Updated image: IMG_20190215_183027.jpg
# ✔️ Updated image: IMG_20190222_162254_439.jpg
# ✔️ Updated image: IMG_20190302_170151.jpg
# ✔️ Updated image: IMG_20190314_092316.jpg
# ✔️ Updated image: IMG_20190329_225057.jpg
# ✔️ Updated image: IMG_20190331_191827.jpg
# ✔️ Updated image: IMG_20190331_191846.jpg
# ✔️ Updated image: IMG_20190407_041342.jpg
# ✔️ Updated image: IMG_20190407_125702_976.jpg
# ✔️ Updated image: IMG_20190412_225133.jpg
# ✔️ Updated image: IMG_20190412_225137.jpg
# ✔️ Updated image: IMG_20190414_001330.jpg
# ✔️ Updated image: IMG_20190414_001357.jpg
# ✔️ Updated image: IMG_20190414_001408.jpg
# ✔️ Updated image: IMG_20190414_232048.jpg
# ✔️ Updated image: IMG_20190417_102113.jpg
# ✔️ Updated image: IMG_20190421_143716.jpg
# ✔️ Updated image: IMG_20190421_143717.jpg
# ✔️ Updated image: IMG_20190423_100713.jpg
# ✔️ Updated image: IMG_20190428_192135.jpg
# ✔️ Updated image: IMG_20190428_192143.jpg
# ✔️ Updated image: IMG_20190428_192147.jpg
# ✔️ Updated image: IMG_20190501_165511.jpg
# ✔️ Updated image: IMG_20190505_145503.jpg
# ✔️ Updated image: IMG_20190505_145504.jpg
# ✔️ Updated image: IMG_20190505_145516.jpg
# ✔️ Updated image: IMG_20190506_063915.jpg
# ✔️ Updated image: IMG_20190509_102410.jpg
# ✔️ Updated image: IMG_20190511_121448.jpg
# ✔️ Updated image: IMG_20190511_121456.jpg
# ✔️ Updated image: IMG_20190515_113305.jpg
# ✔️ Updated image: IMG_20190523_185319.jpg
# ✔️ Updated image: IMG_20190523_185521.jpg
# ✔️ Updated image: IMG_20190523_185926.jpg
# ✔️ Updated image: IMG_20190523_201549.jpg
# ✔️ Updated image: IMG_20190523_201557.jpg
# ✔️ Updated image: IMG_20190523_201600.jpg
# ✔️ Updated image: IMG_20190523_213435.jpg
# ✔️ Updated image: IMG_20190525_221229.jpg
# ✔️ Updated image: IMG_20190526_001441.jpg
# ✔️ Updated image: IMG_20190526_003044.jpg
# ✔️ Updated image: IMG_20190526_003159.jpg
# ✔️ Updated image: IMG_20190530_180543.jpg
# ✔️ Updated image: IMG_20190530_180545.jpg
# ✔️ Updated image: IMG_20190606_131426.jpg
# ✔️ Updated image: IMG_20190606_172545.jpg
# ✔️ Updated image: IMG_20190606_172557.jpg
# ✔️ Updated image: IMG_20190606_172633.jpg
# ✔️ Updated image: IMG_20190606_173728_931.jpg
# ✔️ Updated image: IMG_20190606_174208_213.jpg
# ✔️ Updated image: IMG_20190608_154808.jpg
# ✔️ Updated image: IMG_20190608_155054.jpg
# ✔️ Updated image: IMG_20190608_155320.jpg
# ✔️ Updated image: IMG_20190611_231233.jpg
# ✔️ Updated image: IMG_20190611_231238.jpg
# ✔️ Updated image: IMG_20190617_105030.jpg
# ✔️ Updated image: IMG_20190622_203207_064.jpg
# ✔️ Updated image: IMG_20190623_145428.jpg
# ✔️ Updated image: IMG_20190623_145448.jpg
# ✔️ Updated image: IMG_20190623_160145.jpg
# ✔️ Updated image: IMG_20190717_192422.jpg
# ✔️ Updated image: IMG_20190721_081045.jpg
# ✔️ Updated image: IMG_20190721_140246.jpg
# ✔️ Updated image: IMG_20190721_141336.jpg
# ✔️ Updated image: IMG_20190721_152319.jpg
# ✔️ Updated image: IMG_20190721_155258.jpg
# ✔️ Updated image: IMG_20190721_155302.jpg
# ✔️ Updated image: IMG_20190801_130404.jpg
# ✔️ Updated image: IMG_20190815_003011.jpg
# ✔️ Updated image: IMG_20190815_010723.jpg
# ✔️ Updated image: IMG_20190815_013146.jpg
# ✔️ Updated image: IMG_20190817_074059-je uredil(-a)_.jpg
# ✔️ Updated image: IMG_20190817_074059.jpg
# ✔️ Updated image: IMG_20190817_080317.jpg
# ✔️ Updated image: IMG_20190817_082115.jpg
# ✔️ Updated image: IMG_20190820_151221.jpg
# ✔️ Updated image: IMG_20190820_151228.jpg
# ✔️ Updated image: IMG_20190916_151010.jpg
# ✔️ Updated image: IMG_20190916_151029.jpg
# ✔️ Updated image: IMG_20190916_151139.jpg
# ✔️ Updated image: IMG_20190916_183013.jpg
# ✔️ Updated image: IMG_20190916_183059.jpg
# ✔️ Updated image: IMG_20190924_162249.jpg
# ✔️ Updated image: IMG_20191004_170613_941.jpg
# ✔️ Updated image: IMG_20191025_164451.jpg
# ✔️ Updated image: IMG_20191025_164457.jpg
# ✔️ Updated image: IMG_20191025_164553.jpg
# ✔️ Updated image: IMG_20191025_164607.jpg
# ✔️ Updated image: IMG_20191206_134311.jpg
# ✔️ Updated image: IMG_20191214_133849.jpg
# ✔️ Updated image: IMG_20191229_153628-EFFECTS-je uredil(-a)_.jpg
# ✔️ Updated image: IMG_20191229_153628-EFFECTS.jpg
# ✔️ Updated image: received_533329080543406.jpeg
# ✔️ Updated image: Screenshot_2018-10-23-19-14-33.jpg
# ✔️ Updated video: Snapchat-511662567.mp4
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2019\SVID_20190409_132155~2.mp4: [Errno 22] Invalid argument
# ✔️ Updated video: YouCut_20191027_141212682.mp4
# ✔️ Updated video: YouCut_20191027_141849515.mp4
#
# 📁 Processing folder: Photos from 2019 (2)
# ℹ️ Using reference date: 2019-06-05
# ✔️ Updated image: IMG_20190925_203114_403.jpg
# ✔️ Updated video: YouCut_20190602_230836882.mp4
#
# 📁 Processing folder: Photos from 2020
# ℹ️ Using reference date: 2020-09-08
# ✔️ Updated image: FB_IMG_1596758949919.jpg
# ✔️ Updated image: FB_IMG_1605630798643.jpg
# ✔️ Updated image: IMG_20200209_003430_673.jpg
# ✔️ Updated image: IMG_20200329_191102.jpg
# ✔️ Updated image: IMG_20200417_163035.jpg
# ✔️ Updated image: IMG_20200417_165528.jpg
# ✔️ Updated image: IMG_20200421_183312.jpg
# ✔️ Updated image: IMG_20200423_184207.jpg
# ✔️ Updated image: IMG_20200520_215635_038.jpg
# ✔️ Updated image: IMG_20200711_223711.jpg
# ✔️ Updated image: IMG_20200726_045003.jpg
# ✔️ Updated image: IMG_20200726_050615.jpg
# ✔️ Updated image: IMG_20200726_055605.jpg
# ✔️ Updated image: IMG_20200731_150639.jpg
# ✔️ Updated image: IMG_20200908_185009.jpg
# ✔️ Updated image: IMG_20201010_192840_131.jpg
# ✔️ Updated image: IMG_20201025_141446_539.jpg
# ✔️ Updated image: IMG_20201128_120336_060.jpg
# ✔️ Updated image: InShot_20200914_133111134.jpg
# ✔️ Updated image: received_771219807021715.jpeg
#
# 📁 Processing folder: Photos from 2020 (1)
# ℹ️ Using reference date: 2020-12-30
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2020 (1)\c883afee3c093e0ffba7600e4323f570.mp4: [Errno 22] Invalid argument
# ✔️ Updated image: FB_IMG_1606392250347.jpg
# ✔️ Updated image: IMG_20200808_140938_184.jpg
# ✔️ Updated image: IMG_20200825_202009.jpg
# ✔️ Updated image: IMG_20200825_202511.jpg
# ✔️ Updated image: IMG_20200825_203055.jpg
# ✔️ Updated image: IMG_20200908_184912.jpg
# ✔️ Updated image: IMG_20200908_185125.jpg
# ✔️ Updated image: IMG_20200908_185404.jpg
# ✔️ Updated image: IMG_20200911_074100.jpg
# ✔️ Updated image: IMG_20200912_230245.jpg
# ✔️ Updated image: IMG_20200917_162155.jpg
# ✔️ Updated image: IMG_20200918_222814.jpg
# ✔️ Updated image: IMG_20201026_170929.jpg
# ✔️ Updated image: IMG_20201029_121721.jpg
# ✔️ Updated image: IMG_20201029_121830.jpg
# ✔️ Updated image: IMG_20201029_161052.jpg
# ✔️ Updated image: IMG_20201029_163238-EFFECTS.jpg
# ✔️ Updated image: IMG_20201108_184314_151.jpg
# ✔️ Updated image: IMG_20201109_142832.jpg
# ✔️ Updated image: IMG_20201109_144339.jpg
# ✔️ Updated image: IMG_20201114_224238.jpg
# ✔️ Updated image: IMG_20201117_145429.jpg
# ✔️ Updated image: IMG_20201117_145500.jpg
# ✔️ Updated image: IMG_20201121_084754.jpg
# ✔️ Updated image: IMG_20201121_090859.jpg
# ✔️ Updated image: IMG_20201121_090915.jpg
# ✔️ Updated image: IMG_20201123_181025.jpg
# ✔️ Updated image: IMG_20201124_151920.jpg
# ✔️ Updated image: IMG_20201124_152718.jpg
# ✔️ Updated image: IMG_20201125_090652.jpg
# ✔️ Updated image: IMG_20201125_161022.jpg
# ✔️ Updated image: IMG_20201125_175037_526.jpg
# ✔️ Updated image: IMG_20201128_120315_479.jpg
# ✔️ Updated image: IMG_20201129_153635.jpg
# ✔️ Updated image: IMG_20201129_153638.jpg
# ✔️ Updated image: IMG_20201129_153708.jpg
# ✔️ Updated image: IMG_20201201_152000.jpg
# ✔️ Updated image: IMG_20201201_152015.jpg
# ✔️ Updated image: IMG_20201201_152231.jpg
# ✔️ Updated image: IMG_20201212_151604.jpg
# ✔️ Updated image: IMG_20201212_151645.jpg
# ✔️ Updated image: IMG_20201212_152854.jpg
# ✔️ Updated image: IMG_20201212_152856.jpg
# ✔️ Updated image: IMG_20201212_152858.jpg
# ✔️ Updated image: IMG_20201212_153159.jpg
# ✔️ Updated image: IMG_20201215_175657.jpg
# ✔️ Updated image: IMG_20201222_000744.jpg
# ✔️ Updated image: IMG_20201226_152650.jpg
# ✔️ Updated image: IMG_20201226_152828.jpg
# ✔️ Updated image: IMG_20201226_153803.jpg
# ✔️ Updated image: IMG_20201226_153807.jpg
# ✔️ Updated image: IMG_20201226_155406.jpg
# ✔️ Updated image: IMG_20201226_155505.jpg
# ✔️ Updated image: IMG_20201227_000638.jpg
# ✔️ Updated image: IMG_20201229_122153.jpg
# ✔️ Updated image: IMG_20201230_135735.jpg
# ✔️ Updated image: IMG_20201230_141641.jpg
# ✔️ Updated image: InShot_20201106_105213902.jpg
# ✔️ Updated image: original_5aca8c92-0ef1-4ee2-82c8-e882e4daf698_I(1).jpg
# ✔️ Updated image: original_76d11523-ea3c-4f0a-9a84-23263bee181d_I(1).jpg
# ✔️ Updated image: original_76d11523-ea3c-4f0a-9a84-23263bee181d_I.jpg
# ✔️ Updated image: original_7acbc016-a783-4b27-87c4-c0ab197bf0a8_I(1).jpg
# ✔️ Updated image: original_7acbc016-a783-4b27-87c4-c0ab197bf0a8_I.jpg
# ✔️ Updated image: original_e31cbdb0-930d-4fb7-8eee-35f7ded9f4f2_I(1).jpg
# ✔️ Updated image: original_e31cbdb0-930d-4fb7-8eee-35f7ded9f4f2_I.jpg
# ✔️ Updated video: received_1279229439107312.mp4
# ✔️ Updated image: received_1285222001852285.jpeg
# ✔️ Updated image: received_2629697087359298.jpeg
# ✔️ Updated image: received_648104952521768.jpeg
# ✔️ Updated video: VID_20201205_203130.mp4
# ✔️ Updated video: VID_20201214_105710.mp4
# ✔️ Updated video: VID_20201226_154526.mp4
#
# 📁 Processing folder: Photos from 2020 (2)
# ℹ️ Using reference date: 2020-10-29
# ✔️ Updated image: 20201026_234317.jpg
# ✔️ Updated image: IMG_20200702_150805_382.jpg
# ✔️ Updated image: IMG_20200714_073227.jpg
# ✔️ Updated image: IMG_20200714_081652.jpg
# ✔️ Updated image: IMG_20200714_081659.jpg
# ✔️ Updated image: IMG_20200714_081900.jpg
# ✔️ Updated image: IMG_20200714_082250.jpg
# ✔️ Updated image: IMG_20200714_082258.jpg
# ✔️ Updated image: IMG_20200714_090647.jpg
# ✔️ Updated image: IMG_20200714_090653.jpg
# ✔️ Updated image: IMG_20200714_090905.jpg
# ✔️ Updated image: IMG_20200714_090910.jpg
# ✔️ Updated image: IMG_20200725_164853.jpg
# ✔️ Updated image: IMG_20200725_214239.jpg
# ✔️ Updated image: IMG_20200726_015923.jpg
# ✔️ Updated image: IMG_20200726_015929.jpg
# ✔️ Updated image: IMG_20200726_015933.jpg
# ✔️ Updated image: IMG_20200726_054415.jpg
# ✔️ Updated image: IMG_20200726_055033.jpg
# ✔️ Updated image: IMG_20200726_055157.jpg
# ✔️ Updated image: IMG_20200726_055729.jpg
# ✔️ Updated image: IMG_20200726_055830.jpg
# ✔️ Updated image: IMG_20200726_055834.jpg
# ✔️ Updated image: IMG_20200726_055951.jpg
# ...
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711182550.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711182607.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711182933.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183652.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183656.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183859.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183903.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183910.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183912.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183915.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183939.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711183946.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711184021.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711185319.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711190722.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711190733.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711190806.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711190814.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250711193044.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101146.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101150.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101155.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101208.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101209.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101212.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712101410.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712190301.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712191559.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712191601.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712191612.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712191902.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712192337.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712192401.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712192405.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712192949.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712200757.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250712200759.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250713085509.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250713090926.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250713090929.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250713090933.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250716152932.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250716184921.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718065334.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718065859.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718073011.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718073018.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718074222.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718075935.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718075949.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718083046.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250718120735.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719200352.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719201625.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719201630.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719201825.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719201921.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719202023.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719202227.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719202254.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719202451.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719202532.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250719203956.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250720202219.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250720202323.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250720204739.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250721102447.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250721140545.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250721140616.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250723145017.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250723203747.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250723203750.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250725192542.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250729193934.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250731141726.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250731142429.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250731192236.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250803003409.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250804083645.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250804140649.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250804164548.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250805121528.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250806092302.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250806092309.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250806092310.jpg: Given data isn't JPEG.
# ❌ EXIF update failed for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\IMG20250806092953.jpg: Given data isn't JPEG.
# ✔️ Updated image: IMG_20250319_203504_636.jpg
# ✔️ Updated image: IMG_20250425_205843.jpg
# ✔️ Updated image: IMG_20250430_143351.jpg
# ✔️ Updated image: IMG_20250522_135652_616.jpg
# ✔️ Updated image: IMG_20250522_135657_544.jpg
# ✔️ Updated image: IMG_20250522_135704_837.jpg
# ✔️ Updated image: IMG_20250522_135715_352.jpg
# ✔️ Updated image: IMG_20250522_135904_518.jpg
# ✔️ Updated image: IMG_20250522_135909_636.jpg
# ✔️ Updated image: IMG_20250711_225035.jpg
# ✔️ Updated image: Messenger_creation_0628943C-3AF0-4D2A-9D1E-238B70BE63CA.jpeg
# ✔️ Updated image: Messenger_creation_0C580537-7642-4920-9B04-0A1F23853C87.jpeg
# ✔️ Updated image: Messenger_creation_167D2187-079E-4B03-ACDF-6574697D4682.jpeg
# ✔️ Updated image: Messenger_creation_1ED9DA62-BD52-4344-B892-554D2A1C3064.jpeg
# ✔️ Updated image: Messenger_creation_3B01F0D8-0340-4A16-898F-9B01A8565C65.jpeg
# ✔️ Updated image: Messenger_creation_3DED22BA-2E83-4DB6-A5E3-F1EC2FB51652.jpeg
# ✔️ Updated image: Messenger_creation_412F958B-7149-4012-A700-6BFF91BB64A6.jpeg
# ✔️ Updated image: Messenger_creation_56C470B5-3E8C-40BB-BC89-42C56AC2A024.jpeg
# ✔️ Updated image: Messenger_creation_6011C463-4515-4171-B38A-8DDCE73C5CEF.jpeg
# ✔️ Updated image: Messenger_creation_63D4D11D-358E-4B7C-A3CC-39EDA79B9AC3.jpeg
# ✔️ Updated image: Messenger_creation_6C9717D9-A4B4-4955-9AA1-2DD17F206870.jpeg
# ✔️ Updated image: Messenger_creation_75A1FF1B-634B-4B41-80BC-10DBB45953ED.jpeg
# ✔️ Updated image: Messenger_creation_76581D98-CDE6-42F1-A981-1FC1AFA15300.jpeg
# ✔️ Updated image: Messenger_creation_79771792-83BA-4AF5-B251-760062D89E7B.jpeg
# ✔️ Updated image: Messenger_creation_9AB82EE9-E1DC-4B04-8297-B7452A09FC56.jpeg
# ✔️ Updated image: Messenger_creation_9B1B52E4-3C44-49DB-8589-4F19E7199FDE.jpeg
# ✔️ Updated image: Messenger_creation_9B3227A0-DFD6-49DC-9E2D-61E1A0EFF571.jpeg
# ✔️ Updated image: Messenger_creation_B44E64DF-5659-45FB-94A4-D5440AD73ACD.jpeg
# ✔️ Updated image: Messenger_creation_B8847CE1-22AD-482B-B41A-818CC9066674.jpeg
# ✔️ Updated image: Messenger_creation_DE4FABF9-AB8C-4E06-B02D-A68049D29D1C.jpeg
# ✔️ Updated image: Messenger_creation_DEA141D0-DFC4-477B-BF0D-2D7559BD9357.jpeg
# ✔️ Updated image: Messenger_creation_F46C3471-FB94-402D-AC5C-20632AEE847B.jpeg
# ✔️ Updated image: Messenger_creation_F715A800-8F2C-4AE1-A22B-82DA376C7356.jpeg
# ✔️ Updated image: received_1098952332191611.jpeg
# ✔️ Updated image: received_1270655358043681.jpeg
# ✔️ Updated image: received_4054820238140103.jpeg
# ✔️ Updated image: received_4173915139531918.jpeg
# ✔️ Updated image: received_627673940349950.jpeg
# ✔️ Updated image: received_627712793678301.jpeg
# ✔️ Updated image: received_681299574938053.jpeg
# ✔️ Updated image: received_735590939188062.jpeg
# ✔️ Updated video: VID20250315163923.mp4
# ✔️ Updated video: VID20250324200219.mp4
# ✔️ Updated video: VID20250402150025.mp4
# ✔️ Updated video: VID20250407194210.mp4
# ✔️ Updated video: VID20250420135952.mp4
# ✔️ Updated video: VID20250423202730.mp4
# ✔️ Updated video: VID20250430231645.mp4
# ✔️ Updated video: VID20250502153335.mp4
# ✔️ Updated video: VID20250502153417.mp4
# ✔️ Updated video: VID20250506231345.mp4
# ✔️ Updated video: VID20250519173115.mp4
# ✔️ Updated video: VID20250522215300.mp4
# ✔️ Updated video: VID20250528230417.mp4
# ✔️ Updated video: VID20250611170842.mp4
# ✔️ Updated video: VID20250613032255.mp4
# ✔️ Updated video: VID20250614123337.mp4
# ✔️ Updated video: VID20250614124454.mp4
# ✔️ Updated video: VID20250616231418.mp4
# ✔️ Updated video: VID20250620131248.mp4
# ✔️ Updated video: VID20250625131419.mp4
# ✔️ Updated video: VID20250627222100.mp4
# ✔️ Updated video: VID20250628200402.mp4
# ✔️ Updated video: VID20250628200436.mp4
# ✔️ Updated video: VID20250628201128.mp4
# ✔️ Updated video: VID20250628201132.mp4
# ✔️ Updated video: VID20250630102356.mp4
# ✔️ Updated video: VID20250630102428.mp4
# ✔️ Updated video: VID20250701134607.mp4
# ✔️ Updated video: VID20250705104722.mp4
# ✔️ Updated video: VID20250705122344.mp4
# ✔️ Updated video: VID20250710182934.mp4
# ✔️ Updated video: VID20250710184109.mp4
# ✔️ Updated video: VID20250710203643.mp4
# ✔️ Updated video: VID20250710204532.mp4
# ✔️ Updated video: VID20250711181324.mp4
# ✔️ Updated video: VID20250711183230.mp4
# ✔️ Updated video: VID20250711183658.mp4
# ✔️ Updated video: VID20250711183705.mp4
# ✔️ Updated video: VID20250711184321.mp4
# ✔️ Updated video: VID20250711184416.mp4
# ✔️ Updated video: VID20250711193048.mp4
# ✔️ Updated video: VID20250712101015.mp4
# ✔️ Updated video: VID20250712101349.mp4
# ✔️ Updated video: VID20250712192704.mp4
# ✔️ Updated video: VID20250712192953.mp4
# ✔️ Updated video: VID20250718075739.mp4
# ✔️ Updated video: VID20250720151345.mp4
# ✔️ Updated video: VID20250804164559.mp4
# ❌ Failed to set filesystem times for C:\Users\kuste\Desktop\project\Arhiv slik\Photos from 2025\VID_20250805_054212_982.mp4: [Errno 22] Invalid argument
# ✔️ Updated image: _uhdnature213.jpg
#
# ✅ Done. Folders scanned: 40, Files updated: 2229
